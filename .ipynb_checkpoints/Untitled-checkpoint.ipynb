# %% [markdown]
# # Stock market predictor
# [link to tutorial](https://www.thepythoncode.com/article/stock-price-prediction-in-python-using-tensorflow-2-and-keras)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from yahoo_fin import stock_info as si
from collections import deque

import os
import numpy as np
import pandas as pd
import random

# %%
# set seed, so we cant get the same results after rerunning
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def shuffle_in_unison(a, b):
    # shuffle two arrays in the same away
    state = np.random.get_state()
    np.random.shuffle(a)
    np.random.set_state(state)
    np.random.shuffle(b)

# %%
def shuffle_in_unison(a, b):
    # shuffle two arrays in the same way
    state = np.random.get_state()
    np.random.shuffle(a)
    np.random.set_state(state)
    np.random.shuffle(b)

def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, split_by_date=True,
                test_size=0.2, feature_columns=['adjclose', 'volume', 'open', 'high', 'low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the dataset (both training & testing), default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        split_by_date (bool): whether we split the dataset into training/testing by date, setting it 
            to False will split datasets in a random way
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yahoo_fin library
        df = si.get_data(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    # add date as a column
    if "date" not in df.columns:
        df["date"] = df.index
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['adjclose'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns + ["date"]].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices that are not available in the dataset
    last_sequence = list([s[:len(feature_columns)] for s in sequences]) + list(last_sequence)
    last_sequence = np.array(last_sequence).astype(np.float32)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    if split_by_date:
        # split the dataset into training & testing sets by date (not randomly splitting)
        train_samples = int((1 - test_size) * len(X))
        result["X_train"] = X[:train_samples]
        result["y_train"] = y[:train_samples]
        result["X_test"]  = X[train_samples:]
        result["y_test"]  = y[train_samples:]
        if shuffle:
            # shuffle the datasets for training (if shuffle parameter is set)
            shuffle_in_unison(result["X_train"], result["y_train"])
            shuffle_in_unison(result["X_test"], result["y_test"])
    else:    
        # split the dataset randomly
        result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                                test_size=test_size, shuffle=shuffle)
    # get the list of test set dates
    dates = result["X_test"][:, -1, -1]
    # retrieve test features from the original dataframe
    result["test_df"] = result["df"].loc[dates]
    # remove duplicated dates in the testing dataframe
    result["test_df"] = result["test_df"][~result["test_df"].index.duplicated(keep='first')]
    # remove dates from the training/testing sets & convert to float32
    result["X_train"] = result["X_train"][:, :, :len(feature_columns)].astype(np.float32)
    result["X_test"] = result["X_test"][:, :, :len(feature_columns)].astype(np.float32)
    return result

# %%
def create_model(sequence_length, n_features, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), batch_input_shape=(None, sequence_length, n_features)))
            else:
                model.add(cell(units, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
import os
import time
from tensorflow.keras.layers import LSTM

# Window size or the sequence length
N_STEPS = 50
# Lookup step, 1 is the next day
LOOKUP_STEP = 15
# whether to scale feature columns & output price as well
SCALE = True
scale_str = f"sc-{int(SCALE)}"
# whether to shuffle the dataset
SHUFFLE = True
shuffle_str = f"sh-{int(SHUFFLE)}"
# whether to split the training/testing set by date
SPLIT_BY_DATE = False
split_by_date_str = f"sbd-{int(SPLIT_BY_DATE)}"
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["adjclose", "volume", "open", "high", "low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 2
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False
### training parameters
# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 500
# Amazon stock market
ticker = "AMZN"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{shuffle_str}-{scale_str}-{split_by_date_str}-\
{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, scale=SCALE, split_by_date=SPLIT_BY_DATE, 
                shuffle=SHUFFLE, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, 
                feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, len(FEATURE_COLUMNS), loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
# train the model and save the weights whenever we see 
# a new optimal model using ModelCheckpoint
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
# Out:
# Epoch 1/500
#  1/74 [..............................] - ETA: 0s - loss: 0.0133 - mean_absolute_error: 0.0880WARNING:tensorflow:From c:\users\omgda\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#  2/74 [..............................] - ETA: 30s - loss: 0.0072 - mean_absolute_error: 0.0631WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2745s vs `on_train_batch_end` time: 0.5686s). Check your callbacks.
# 74/74 [==============================] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0212
# Epoch 00001: val_loss improved from inf to 0.00022, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 22s 300ms/step - loss: 0.0011 - mean_absolute_error: 0.0212 - val_loss: 2.1615e-04 - val_mean_absolute_error: 0.0091
# Epoch 2/500
# 74/74 [==============================] - ETA: 0s - loss: 4.4350e-04 - mean_absolute_error: 0.0145
# Epoch 00002: val_loss improved from 0.00022 to 0.00014, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 282ms/step - loss: 4.4350e-04 - mean_absolute_error: 0.0145 - val_loss: 1.3790e-04 - val_mean_absolute_error: 0.0074
# Epoch 3/500
# 74/74 [==============================] - ETA: 0s - loss: 3.8059e-04 - mean_absolute_error: 0.0130
# Epoch 00003: val_loss did not improve from 0.00014
# 74/74 [==============================] - 21s 279ms/step - loss: 3.8059e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4350e-04 - val_mean_absolute_error: 0.0088
# Epoch 4/500
# 74/74 [==============================] - ETA: 0s - loss: 5.3682e-04 - mean_absolute_error: 0.0169
# Epoch 00004: val_loss did not improve from 0.00014
# 74/74 [==============================] - 22s 299ms/step - loss: 5.3682e-04 - mean_absolute_error: 0.0169 - val_loss: 1.4681e-04 - val_mean_absolute_error: 0.0086
# Epoch 5/500
# 74/74 [==============================] - ETA: 0s - loss: 3.7145e-04 - mean_absolute_error: 0.0136
# Epoch 00005: val_loss did not improve from 0.00014
# 74/74 [==============================] - 21s 277ms/step - loss: 3.7145e-04 - mean_absolute_error: 0.0136 - val_loss: 1.4524e-04 - val_mean_absolute_error: 0.0096
# Epoch 6/500
# 74/74 [==============================] - ETA: 0s - loss: 3.4071e-04 - mean_absolute_error: 0.0127
# Epoch 00006: val_loss did not improve from 0.00014
# 74/74 [==============================] - 22s 293ms/step - loss: 3.4071e-04 - mean_absolute_error: 0.0127 - val_loss: 2.2694e-04 - val_mean_absolute_error: 0.0100
# Epoch 7/500
# 74/74 [==============================] - ETA: 0s - loss: 3.6855e-04 - mean_absolute_error: 0.0138
# Epoch 00007: val_loss did not improve from 0.00014
# 74/74 [==============================] - 26s 348ms/step - loss: 3.6855e-04 - mean_absolute_error: 0.0138 - val_loss: 1.7313e-04 - val_mean_absolute_error: 0.0095
# Epoch 8/500
# 74/74 [==============================] - ETA: 0s - loss: 3.6106e-04 - mean_absolute_error: 0.0127
# Epoch 00008: val_loss did not improve from 0.00014
# 74/74 [==============================] - 21s 287ms/step - loss: 3.6106e-04 - mean_absolute_error: 0.0127 - val_loss: 1.8200e-04 - val_mean_absolute_error: 0.0080
# Epoch 9/500
# 74/74 [==============================] - ETA: 0s - loss: 4.1137e-04 - mean_absolute_error: 0.0150
# Epoch 00009: val_loss did not improve from 0.00014
# 74/74 [==============================] - 22s 293ms/step - loss: 4.1137e-04 - mean_absolute_error: 0.0150 - val_loss: 1.4375e-04 - val_mean_absolute_error: 0.0075
# Epoch 10/500
# 74/74 [==============================] - ETA: 0s - loss: 3.4494e-04 - mean_absolute_error: 0.0130
# Epoch 00010: val_loss did not improve from 0.00014
# 74/74 [==============================] - 23s 315ms/step - loss: 3.4494e-04 - mean_absolute_error: 0.0130 - val_loss: 3.8069e-04 - val_mean_absolute_error: 0.0154
# Epoch 11/500
# 74/74 [==============================] - ETA: 0s - loss: 3.2201e-04 - mean_absolute_error: 0.0127
# Epoch 00011: val_loss did not improve from 0.00014
# 74/74 [==============================] - 21s 286ms/step - loss: 3.2201e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4321e-04 - val_mean_absolute_error: 0.0083
# Epoch 12/500
# 74/74 [==============================] - ETA: 0s - loss: 3.2330e-04 - mean_absolute_error: 0.0128
# Epoch 00012: val_loss did not improve from 0.00014
# 74/74 [==============================] - 21s 288ms/step - loss: 3.2330e-04 - mean_absolute_error: 0.0128 - val_loss: 2.2656e-04 - val_mean_absolute_error: 0.0104
# Epoch 13/500
# 74/74 [==============================] - ETA: 0s - loss: 3.8556e-04 - mean_absolute_error: 0.0135
# Epoch 00013: val_loss did not improve from 0.00014
# 74/74 [==============================] - 22s 295ms/step - loss: 3.8556e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6306e-04 - val_mean_absolute_error: 0.0104
# Epoch 14/500
# 74/74 [==============================] - ETA: 0s - loss: 3.2426e-04 - mean_absolute_error: 0.0126
# Epoch 00014: val_loss did not improve from 0.00014
# 74/74 [==============================] - 22s 303ms/step - loss: 3.2426e-04 - mean_absolute_error: 0.0126 - val_loss: 1.9805e-04 - val_mean_absolute_error: 0.0089
# Epoch 15/500
# 74/74 [==============================] - ETA: 0s - loss: 3.1342e-04 - mean_absolute_error: 0.0121
# Epoch 00015: val_loss did not improve from 0.00014
# 74/74 [==============================] - 24s 323ms/step - loss: 3.1342e-04 - mean_absolute_error: 0.0121 - val_loss: 2.2444e-04 - val_mean_absolute_error: 0.0098
# Epoch 16/500
# 74/74 [==============================] - ETA: 0s - loss: 2.8449e-04 - mean_absolute_error: 0.0117
# Epoch 00016: val_loss improved from 0.00014 to 0.00013, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 22s 301ms/step - loss: 2.8449e-04 - mean_absolute_error: 0.0117 - val_loss: 1.2807e-04 - val_mean_absolute_error: 0.0076
# Epoch 17/500
# 74/74 [==============================] - ETA: 0s - loss: 2.9010e-04 - mean_absolute_error: 0.0122
# Epoch 00017: val_loss did not improve from 0.00013
# 74/74 [==============================] - 22s 296ms/step - loss: 2.9010e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2782e-04 - val_mean_absolute_error: 0.0128
# Epoch 18/500
# 74/74 [==============================] - ETA: 0s - loss: 3.4497e-04 - mean_absolute_error: 0.0130
# Epoch 00018: val_loss did not improve from 0.00013
# 74/74 [==============================] - 26s 348ms/step - loss: 3.4497e-04 - mean_absolute_error: 0.0130 - val_loss: 3.9648e-04 - val_mean_absolute_error: 0.0129
# Epoch 19/500
# 74/74 [==============================] - ETA: 0s - loss: 3.1100e-04 - mean_absolute_error: 0.0128
# Epoch 00019: val_loss did not improve from 0.00013
# 74/74 [==============================] - 25s 333ms/step - loss: 3.1100e-04 - mean_absolute_error: 0.0128 - val_loss: 1.3411e-04 - val_mean_absolute_error: 0.0074
# Epoch 20/500
# 74/74 [==============================] - ETA: 0s - loss: 3.3177e-04 - mean_absolute_error: 0.0129
# Epoch 00020: val_loss did not improve from 0.00013
# 74/74 [==============================] - 25s 339ms/step - loss: 3.3177e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4746e-04 - val_mean_absolute_error: 0.0083
# Epoch 21/500
# 74/74 [==============================] - ETA: 0s - loss: 2.9601e-04 - mean_absolute_error: 0.0122
# Epoch 00021: val_loss did not improve from 0.00013
# 74/74 [==============================] - 22s 297ms/step - loss: 2.9601e-04 - mean_absolute_error: 0.0122 - val_loss: 1.4953e-04 - val_mean_absolute_error: 0.0077
# Epoch 22/500
# 74/74 [==============================] - ETA: 0s - loss: 3.0863e-04 - mean_absolute_error: 0.0126
# Epoch 00022: val_loss did not improve from 0.00013
# 74/74 [==============================] - 24s 320ms/step - loss: 3.0863e-04 - mean_absolute_error: 0.0126 - val_loss: 1.7781e-04 - val_mean_absolute_error: 0.0085
# Epoch 23/500
# 74/74 [==============================] - ETA: 0s - loss: 3.6016e-04 - mean_absolute_error: 0.0132
# Epoch 00023: val_loss did not improve from 0.00013
# 74/74 [==============================] - 22s 294ms/step - loss: 3.6016e-04 - mean_absolute_error: 0.0132 - val_loss: 4.2581e-04 - val_mean_absolute_error: 0.0152
# Epoch 24/500
# 74/74 [==============================] - ETA: 0s - loss: 3.7104e-04 - mean_absolute_error: 0.0138
# Epoch 00024: val_loss did not improve from 0.00013
# 74/74 [==============================] - 24s 318ms/step - loss: 3.7104e-04 - mean_absolute_error: 0.0138 - val_loss: 1.7172e-04 - val_mean_absolute_error: 0.0095
# Epoch 25/500
# 74/74 [==============================] - ETA: 0s - loss: 2.9657e-04 - mean_absolute_error: 0.0125
# Epoch 00025: val_loss did not improve from 0.00013
# 74/74 [==============================] - 24s 318ms/step - loss: 2.9657e-04 - mean_absolute_error: 0.0125 - val_loss: 1.7005e-04 - val_mean_absolute_error: 0.0091
# Epoch 26/500
# 74/74 [==============================] - ETA: 0s - loss: 3.1641e-04 - mean_absolute_error: 0.0131
# Epoch 00026: val_loss did not improve from 0.00013
# 74/74 [==============================] - 22s 291ms/step - loss: 3.1641e-04 - mean_absolute_error: 0.0131 - val_loss: 2.0468e-04 - val_mean_absolute_error: 0.0091
# Epoch 27/500
# 74/74 [==============================] - ETA: 0s - loss: 2.9500e-04 - mean_absolute_error: 0.0126
# Epoch 00027: val_loss improved from 0.00013 to 0.00013, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 23s 308ms/step - loss: 2.9500e-04 - mean_absolute_error: 0.0126 - val_loss: 1.2725e-04 - val_mean_absolute_error: 0.0076
# Epoch 28/500
# 74/74 [==============================] - ETA: 0s - loss: 2.8013e-04 - mean_absolute_error: 0.0122
# Epoch 00028: val_loss did not improve from 0.00013
# 74/74 [==============================] - 23s 316ms/step - loss: 2.8013e-04 - mean_absolute_error: 0.0122 - val_loss: 1.7002e-04 - val_mean_absolute_error: 0.0087
# Epoch 29/500
# 74/74 [==============================] - ETA: 0s - loss: 3.0306e-04 - mean_absolute_error: 0.0128
# Epoch 00029: val_loss did not improve from 0.00013
# 74/74 [==============================] - 22s 294ms/step - loss: 3.0306e-04 - mean_absolute_error: 0.0128 - val_loss: 4.2754e-04 - val_mean_absolute_error: 0.0154
# Epoch 30/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7490e-04 - mean_absolute_error: 0.0124
# Epoch 00030: val_loss did not improve from 0.00013
# 74/74 [==============================] - 24s 326ms/step - loss: 2.7490e-04 - mean_absolute_error: 0.0124 - val_loss: 1.9447e-04 - val_mean_absolute_error: 0.0094
# Epoch 31/500
# 74/74 [==============================] - ETA: 0s - loss: 3.1338e-04 - mean_absolute_error: 0.0130
# Epoch 00031: val_loss did not improve from 0.00013
# 74/74 [==============================] - 22s 296ms/step - loss: 3.1338e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1251e-04 - val_mean_absolute_error: 0.0091
# Epoch 32/500
# 74/74 [==============================] - ETA: 0s - loss: 2.8127e-04 - mean_absolute_error: 0.0127
# Epoch 00032: val_loss did not improve from 0.00013
# 74/74 [==============================] - 23s 313ms/step - loss: 2.8127e-04 - mean_absolute_error: 0.0127 - val_loss: 1.3941e-04 - val_mean_absolute_error: 0.0074
# Epoch 33/500
# 74/74 [==============================] - ETA: 0s - loss: 2.8634e-04 - mean_absolute_error: 0.0127
# Epoch 00033: val_loss improved from 0.00013 to 0.00012, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 24s 327ms/step - loss: 2.8634e-04 - mean_absolute_error: 0.0127 - val_loss: 1.2020e-04 - val_mean_absolute_error: 0.0067
# Epoch 34/500
# 74/74 [==============================] - ETA: 0s - loss: 3.2662e-04 - mean_absolute_error: 0.0133
# Epoch 00034: val_loss did not improve from 0.00012
# 74/74 [==============================] - 23s 314ms/step - loss: 3.2662e-04 - mean_absolute_error: 0.0133 - val_loss: 2.2003e-04 - val_mean_absolute_error: 0.0100
# Epoch 35/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7329e-04 - mean_absolute_error: 0.0125
# Epoch 00035: val_loss did not improve from 0.00012
# 74/74 [==============================] - 21s 278ms/step - loss: 2.7329e-04 - mean_absolute_error: 0.0125 - val_loss: 1.3381e-04 - val_mean_absolute_error: 0.0076
# Epoch 36/500
# 74/74 [==============================] - ETA: 0s - loss: 3.0693e-04 - mean_absolute_error: 0.0131
# Epoch 00036: val_loss did not improve from 0.00012
# 74/74 [==============================] - 22s 299ms/step - loss: 3.0693e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4320e-04 - val_mean_absolute_error: 0.0086
# Epoch 37/500
# 74/74 [==============================] - ETA: 0s - loss: 2.6260e-04 - mean_absolute_error: 0.0121
# Epoch 00037: val_loss improved from 0.00012 to 0.00012, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 281ms/step - loss: 2.6260e-04 - mean_absolute_error: 0.0121 - val_loss: 1.2015e-04 - val_mean_absolute_error: 0.0066
# Epoch 38/500
# 74/74 [==============================] - ETA: 0s - loss: 2.8250e-04 - mean_absolute_error: 0.0126
# Epoch 00038: val_loss did not improve from 0.00012
# 74/74 [==============================] - 20s 277ms/step - loss: 2.8250e-04 - mean_absolute_error: 0.0126 - val_loss: 1.3438e-04 - val_mean_absolute_error: 0.0080
# Epoch 39/500
# 74/74 [==============================] - ETA: 0s - loss: 3.3866e-04 - mean_absolute_error: 0.0135
# Epoch 00039: val_loss did not improve from 0.00012
# 74/74 [==============================] - 20s 275ms/step - loss: 3.3866e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5162e-04 - val_mean_absolute_error: 0.0110
# Epoch 40/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7935e-04 - mean_absolute_error: 0.0126
# Epoch 00040: val_loss did not improve from 0.00012
# 74/74 [==============================] - 21s 281ms/step - loss: 2.7935e-04 - mean_absolute_error: 0.0126 - val_loss: 1.7528e-04 - val_mean_absolute_error: 0.0083
# Epoch 41/500
# 74/74 [==============================] - ETA: 0s - loss: 2.6036e-04 - mean_absolute_error: 0.0124
# Epoch 00041: val_loss did not improve from 0.00012
# 74/74 [==============================] - 22s 292ms/step - loss: 2.6036e-04 - mean_absolute_error: 0.0124 - val_loss: 1.2185e-04 - val_mean_absolute_error: 0.0071
# Epoch 42/500
# 74/74 [==============================] - ETA: 0s - loss: 2.6353e-04 - mean_absolute_error: 0.0124
# Epoch 00042: val_loss did not improve from 0.00012
# 74/74 [==============================] - 22s 293ms/step - loss: 2.6353e-04 - mean_absolute_error: 0.0124 - val_loss: 1.5539e-04 - val_mean_absolute_error: 0.0088
# Epoch 43/500
# 74/74 [==============================] - ETA: 0s - loss: 3.0428e-04 - mean_absolute_error: 0.0130
# Epoch 00043: val_loss did not improve from 0.00012
# 74/74 [==============================] - 21s 282ms/step - loss: 3.0428e-04 - mean_absolute_error: 0.0130 - val_loss: 3.0354e-04 - val_mean_absolute_error: 0.0130
# Epoch 44/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7111e-04 - mean_absolute_error: 0.0127
# Epoch 00044: val_loss did not improve from 0.00012
# 74/74 [==============================] - 21s 283ms/step - loss: 2.7111e-04 - mean_absolute_error: 0.0127 - val_loss: 1.2754e-04 - val_mean_absolute_error: 0.0081
# Epoch 45/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7161e-04 - mean_absolute_error: 0.0125
# Epoch 00045: val_loss improved from 0.00012 to 0.00012, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 278ms/step - loss: 2.7161e-04 - mean_absolute_error: 0.0125 - val_loss: 1.1926e-04 - val_mean_absolute_error: 0.0066
# Epoch 46/500
# 74/74 [==============================] - ETA: 0s - loss: 2.6328e-04 - mean_absolute_error: 0.0122
# Epoch 00046: val_loss did not improve from 0.00012
# 74/74 [==============================] - 20s 271ms/step - loss: 2.6328e-04 - mean_absolute_error: 0.0122 - val_loss: 1.2554e-04 - val_mean_absolute_error: 0.0073
# Epoch 47/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7838e-04 - mean_absolute_error: 0.0127
# Epoch 00047: val_loss did not improve from 0.00012
# 74/74 [==============================] - 21s 289ms/step - loss: 2.7838e-04 - mean_absolute_error: 0.0127 - val_loss: 1.9580e-04 - val_mean_absolute_error: 0.0098
# Epoch 48/500
# 74/74 [==============================] - ETA: 0s - loss: 2.9364e-04 - mean_absolute_error: 0.0129
# Epoch 00048: val_loss did not improve from 0.00012
# 74/74 [==============================] - 21s 281ms/step - loss: 2.9364e-04 - mean_absolute_error: 0.0129 - val_loss: 1.3135e-04 - val_mean_absolute_error: 0.0072
# Epoch 49/500
# 74/74 [==============================] - ETA: 0s - loss: 2.6243e-04 - mean_absolute_error: 0.0126
# Epoch 00049: val_loss did not improve from 0.00012
# 74/74 [==============================] - 22s 293ms/step - loss: 2.6243e-04 - mean_absolute_error: 0.0126 - val_loss: 1.3711e-04 - val_mean_absolute_error: 0.0078
# Epoch 50/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5460e-04 - mean_absolute_error: 0.0123
# Epoch 00050: val_loss did not improve from 0.00012
# 74/74 [==============================] - 20s 275ms/step - loss: 2.5460e-04 - mean_absolute_error: 0.0123 - val_loss: 2.4835e-04 - val_mean_absolute_error: 0.0105
# Epoch 51/500
# 74/74 [==============================] - ETA: 0s - loss: 2.6630e-04 - mean_absolute_error: 0.0126
# Epoch 00051: val_loss did not improve from 0.00012
# 74/74 [==============================] - 20s 275ms/step - loss: 2.6630e-04 - mean_absolute_error: 0.0126 - val_loss: 1.3850e-04 - val_mean_absolute_error: 0.0080
# Epoch 52/500
# 74/74 [==============================] - ETA: 0s - loss: 2.4100e-04 - mean_absolute_error: 0.0122
# Epoch 00052: val_loss improved from 0.00012 to 0.00011, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 277ms/step - loss: 2.4100e-04 - mean_absolute_error: 0.0122 - val_loss: 1.1133e-04 - val_mean_absolute_error: 0.0068
# Epoch 53/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5034e-04 - mean_absolute_error: 0.0122
# Epoch 00053: val_loss did not improve from 0.00011
# 74/74 [==============================] - 20s 275ms/step - loss: 2.5034e-04 - mean_absolute_error: 0.0122 - val_loss: 1.4226e-04 - val_mean_absolute_error: 0.0081
# Epoch 54/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7446e-04 - mean_absolute_error: 0.0130
# Epoch 00054: val_loss improved from 0.00011 to 0.00011, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 278ms/step - loss: 2.7446e-04 - mean_absolute_error: 0.0130 - val_loss: 1.0677e-04 - val_mean_absolute_error: 0.0064
# Epoch 55/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5851e-04 - mean_absolute_error: 0.0126
# Epoch 00055: val_loss did not improve from 0.00011
# 74/74 [==============================] - 20s 276ms/step - loss: 2.5851e-04 - mean_absolute_error: 0.0126 - val_loss: 1.2325e-04 - val_mean_absolute_error: 0.0071
# Epoch 56/500
# 74/74 [==============================] - ETA: 0s - loss: 2.9767e-04 - mean_absolute_error: 0.0135
# Epoch 00056: val_loss did not improve from 0.00011
# 74/74 [==============================] - 21s 285ms/step - loss: 2.9767e-04 - mean_absolute_error: 0.0135 - val_loss: 2.2691e-04 - val_mean_absolute_error: 0.0109
# Epoch 57/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7172e-04 - mean_absolute_error: 0.0130
# Epoch 00057: val_loss did not improve from 0.00011
# 74/74 [==============================] - 20s 276ms/step - loss: 2.7172e-04 - mean_absolute_error: 0.0130 - val_loss: 2.9055e-04 - val_mean_absolute_error: 0.0130
# Epoch 58/500
# 74/74 [==============================] - ETA: 0s - loss: 2.7749e-04 - mean_absolute_error: 0.0130
# Epoch 00058: val_loss did not improve from 0.00011
# 74/74 [==============================] - 21s 284ms/step - loss: 2.7749e-04 - mean_absolute_error: 0.0130 - val_loss: 1.0887e-04 - val_mean_absolute_error: 0.0073
# Epoch 59/500
# 74/74 [==============================] - ETA: 0s - loss: 2.4169e-04 - mean_absolute_error: 0.0125
# Epoch 00059: val_loss did not improve from 0.00011
# 74/74 [==============================] - 21s 290ms/step - loss: 2.4169e-04 - mean_absolute_error: 0.0125 - val_loss: 1.2980e-04 - val_mean_absolute_error: 0.0084
# Epoch 60/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3662e-04 - mean_absolute_error: 0.0124
# Epoch 00060: val_loss did not improve from 0.00011
# 74/74 [==============================] - 21s 279ms/step - loss: 2.3662e-04 - mean_absolute_error: 0.0124 - val_loss: 1.1687e-04 - val_mean_absolute_error: 0.0071
# Epoch 61/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3171e-04 - mean_absolute_error: 0.0123
# Epoch 00061: val_loss improved from 0.00011 to 0.00010, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 283ms/step - loss: 2.3171e-04 - mean_absolute_error: 0.0123 - val_loss: 1.0313e-04 - val_mean_absolute_error: 0.0073
# Epoch 62/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2042e-04 - mean_absolute_error: 0.0120
# Epoch 00062: val_loss did not improve from 0.00010
# 74/74 [==============================] - 21s 279ms/step - loss: 2.2042e-04 - mean_absolute_error: 0.0120 - val_loss: 2.0765e-04 - val_mean_absolute_error: 0.0108
# Epoch 63/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3021e-04 - mean_absolute_error: 0.0121
# Epoch 00063: val_loss did not improve from 0.00010
# 74/74 [==============================] - 20s 273ms/step - loss: 2.3021e-04 - mean_absolute_error: 0.0121 - val_loss: 1.3353e-04 - val_mean_absolute_error: 0.0077
# Epoch 64/500
# 74/74 [==============================] - ETA: 0s - loss: 2.8119e-04 - mean_absolute_error: 0.0130
# Epoch 00064: val_loss did not improve from 0.00010
# 74/74 [==============================] - 20s 275ms/step - loss: 2.8119e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2893e-04 - val_mean_absolute_error: 0.0098
# Epoch 65/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3709e-04 - mean_absolute_error: 0.0123
# Epoch 00065: val_loss did not improve from 0.00010
# 74/74 [==============================] - 23s 306ms/step - loss: 2.3709e-04 - mean_absolute_error: 0.0123 - val_loss: 1.0765e-04 - val_mean_absolute_error: 0.0066
# Epoch 66/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5404e-04 - mean_absolute_error: 0.0125
# Epoch 00066: val_loss did not improve from 0.00010
# 74/74 [==============================] - 22s 301ms/step - loss: 2.5404e-04 - mean_absolute_error: 0.0125 - val_loss: 1.5942e-04 - val_mean_absolute_error: 0.0081
# Epoch 67/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5949e-04 - mean_absolute_error: 0.0127
# Epoch 00067: val_loss did not improve from 0.00010
# 74/74 [==============================] - 22s 293ms/step - loss: 2.5949e-04 - mean_absolute_error: 0.0127 - val_loss: 1.0843e-04 - val_mean_absolute_error: 0.0069
# Epoch 68/500
# 74/74 [==============================] - ETA: 0s - loss: 2.4728e-04 - mean_absolute_error: 0.0122
# Epoch 00068: val_loss improved from 0.00010 to 0.00010, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 23s 308ms/step - loss: 2.4728e-04 - mean_absolute_error: 0.0122 - val_loss: 9.9113e-05 - val_mean_absolute_error: 0.0066
# Epoch 69/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1802e-04 - mean_absolute_error: 0.0118
# Epoch 00069: val_loss improved from 0.00010 to 0.00009, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 22s 299ms/step - loss: 2.1802e-04 - mean_absolute_error: 0.0118 - val_loss: 9.4130e-05 - val_mean_absolute_error: 0.0068
# Epoch 70/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3675e-04 - mean_absolute_error: 0.0123
# Epoch 00070: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 280ms/step - loss: 2.3675e-04 - mean_absolute_error: 0.0123 - val_loss: 1.0370e-04 - val_mean_absolute_error: 0.0067
# Epoch 71/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3652e-04 - mean_absolute_error: 0.0124
# Epoch 00071: val_loss improved from 0.00009 to 0.00009, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 279ms/step - loss: 2.3652e-04 - mean_absolute_error: 0.0124 - val_loss: 9.2865e-05 - val_mean_absolute_error: 0.0075
# Epoch 72/500
# 74/74 [==============================] - ETA: 0s - loss: 3.0624e-04 - mean_absolute_error: 0.0138
# Epoch 00072: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 289ms/step - loss: 3.0624e-04 - mean_absolute_error: 0.0138 - val_loss: 1.2797e-04 - val_mean_absolute_error: 0.0073
# Epoch 73/500
# 74/74 [==============================] - ETA: 0s - loss: 2.4718e-04 - mean_absolute_error: 0.0127
# Epoch 00073: val_loss improved from 0.00009 to 0.00009, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 286ms/step - loss: 2.4718e-04 - mean_absolute_error: 0.0127 - val_loss: 9.2222e-05 - val_mean_absolute_error: 0.0062
# Epoch 74/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3162e-04 - mean_absolute_error: 0.0125
# Epoch 00074: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 292ms/step - loss: 2.3162e-04 - mean_absolute_error: 0.0125 - val_loss: 1.1614e-04 - val_mean_absolute_error: 0.0085
# Epoch 75/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1166e-04 - mean_absolute_error: 0.0120
# Epoch 00075: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 289ms/step - loss: 2.1166e-04 - mean_absolute_error: 0.0120 - val_loss: 1.2081e-04 - val_mean_absolute_error: 0.0069
# Epoch 76/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2647e-04 - mean_absolute_error: 0.0122
# Epoch 00076: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 294ms/step - loss: 2.2647e-04 - mean_absolute_error: 0.0122 - val_loss: 9.3257e-05 - val_mean_absolute_error: 0.0064
# Epoch 77/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5134e-04 - mean_absolute_error: 0.0127
# Epoch 00077: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 287ms/step - loss: 2.5134e-04 - mean_absolute_error: 0.0127 - val_loss: 2.9624e-04 - val_mean_absolute_error: 0.0139
# Epoch 78/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5616e-04 - mean_absolute_error: 0.0126
# Epoch 00078: val_loss improved from 0.00009 to 0.00009, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 21s 286ms/step - loss: 2.5616e-04 - mean_absolute_error: 0.0126 - val_loss: 8.7893e-05 - val_mean_absolute_error: 0.0061
# Epoch 79/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1394e-04 - mean_absolute_error: 0.0118
# Epoch 00079: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 287ms/step - loss: 2.1394e-04 - mean_absolute_error: 0.0118 - val_loss: 9.0010e-05 - val_mean_absolute_error: 0.0064
# Epoch 80/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0384e-04 - mean_absolute_error: 0.0116
# Epoch 00080: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 296ms/step - loss: 2.0384e-04 - mean_absolute_error: 0.0116 - val_loss: 1.1426e-04 - val_mean_absolute_error: 0.0075
# Epoch 81/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1094e-04 - mean_absolute_error: 0.0118
# Epoch 00081: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 284ms/step - loss: 2.1094e-04 - mean_absolute_error: 0.0118 - val_loss: 1.5069e-04 - val_mean_absolute_error: 0.0088
# Epoch 82/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2687e-04 - mean_absolute_error: 0.0121
# Epoch 00082: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 286ms/step - loss: 2.2687e-04 - mean_absolute_error: 0.0121 - val_loss: 8.8870e-05 - val_mean_absolute_error: 0.0062
# Epoch 83/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1473e-04 - mean_absolute_error: 0.0117
# Epoch 00083: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 286ms/step - loss: 2.1473e-04 - mean_absolute_error: 0.0117 - val_loss: 1.4466e-04 - val_mean_absolute_error: 0.0093
# Epoch 84/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3932e-04 - mean_absolute_error: 0.0125
# Epoch 00084: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 295ms/step - loss: 2.3932e-04 - mean_absolute_error: 0.0125 - val_loss: 1.2717e-04 - val_mean_absolute_error: 0.0075
# Epoch 85/500
# 74/74 [==============================] - ETA: 0s - loss: 2.4079e-04 - mean_absolute_error: 0.0126
# Epoch 00085: val_loss did not improve from 0.00009
# 74/74 [==============================] - 23s 308ms/step - loss: 2.4079e-04 - mean_absolute_error: 0.0126 - val_loss: 1.2821e-04 - val_mean_absolute_error: 0.0076
# Epoch 86/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1884e-04 - mean_absolute_error: 0.0120
# Epoch 00086: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 294ms/step - loss: 2.1884e-04 - mean_absolute_error: 0.0120 - val_loss: 1.0447e-04 - val_mean_absolute_error: 0.0073
# Epoch 87/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2435e-04 - mean_absolute_error: 0.0120
# Epoch 00087: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 288ms/step - loss: 2.2435e-04 - mean_absolute_error: 0.0120 - val_loss: 1.0397e-04 - val_mean_absolute_error: 0.0066
# Epoch 88/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2329e-04 - mean_absolute_error: 0.0122
# Epoch 00088: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 282ms/step - loss: 2.2329e-04 - mean_absolute_error: 0.0122 - val_loss: 1.4798e-04 - val_mean_absolute_error: 0.0083
# Epoch 89/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0846e-04 - mean_absolute_error: 0.0118
# Epoch 00089: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 294ms/step - loss: 2.0846e-04 - mean_absolute_error: 0.0118 - val_loss: 1.9247e-04 - val_mean_absolute_error: 0.0115
# Epoch 90/500
# 74/74 [==============================] - ETA: 0s - loss: 2.4658e-04 - mean_absolute_error: 0.0128
# Epoch 00090: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 292ms/step - loss: 2.4658e-04 - mean_absolute_error: 0.0128 - val_loss: 9.4376e-05 - val_mean_absolute_error: 0.0072
# Epoch 91/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2610e-04 - mean_absolute_error: 0.0122
# Epoch 00091: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 273ms/step - loss: 2.2610e-04 - mean_absolute_error: 0.0122 - val_loss: 9.7772e-05 - val_mean_absolute_error: 0.0065
# Epoch 92/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0741e-04 - mean_absolute_error: 0.0117
# Epoch 00092: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 277ms/step - loss: 2.0741e-04 - mean_absolute_error: 0.0117 - val_loss: 9.5525e-05 - val_mean_absolute_error: 0.0067
# Epoch 93/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0958e-04 - mean_absolute_error: 0.0118
# Epoch 00093: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 273ms/step - loss: 2.0958e-04 - mean_absolute_error: 0.0118 - val_loss: 1.2041e-04 - val_mean_absolute_error: 0.0076
# Epoch 94/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0865e-04 - mean_absolute_error: 0.0117
# Epoch 00094: val_loss improved from 0.00009 to 0.00009, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 20s 275ms/step - loss: 2.0865e-04 - mean_absolute_error: 0.0117 - val_loss: 8.7264e-05 - val_mean_absolute_error: 0.0066
# Epoch 95/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2444e-04 - mean_absolute_error: 0.0121
# Epoch 00095: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 286ms/step - loss: 2.2444e-04 - mean_absolute_error: 0.0121 - val_loss: 1.0199e-04 - val_mean_absolute_error: 0.0071
# Epoch 96/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2147e-04 - mean_absolute_error: 0.0122
# Epoch 00096: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 276ms/step - loss: 2.2147e-04 - mean_absolute_error: 0.0122 - val_loss: 1.1897e-04 - val_mean_absolute_error: 0.0077
# Epoch 97/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2000e-04 - mean_absolute_error: 0.0120
# Epoch 00097: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 280ms/step - loss: 2.2000e-04 - mean_absolute_error: 0.0120 - val_loss: 9.7062e-05 - val_mean_absolute_error: 0.0065
# Epoch 98/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3505e-04 - mean_absolute_error: 0.0122
# Epoch 00098: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 282ms/step - loss: 2.3505e-04 - mean_absolute_error: 0.0122 - val_loss: 9.5341e-05 - val_mean_absolute_error: 0.0063
# Epoch 99/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2352e-04 - mean_absolute_error: 0.0122
# Epoch 00099: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 278ms/step - loss: 2.2352e-04 - mean_absolute_error: 0.0122 - val_loss: 1.5102e-04 - val_mean_absolute_error: 0.0087
# Epoch 100/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2412e-04 - mean_absolute_error: 0.0120
# Epoch 00100: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 278ms/step - loss: 2.2412e-04 - mean_absolute_error: 0.0120 - val_loss: 1.4073e-04 - val_mean_absolute_error: 0.0076
# Epoch 101/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1325e-04 - mean_absolute_error: 0.0119
# Epoch 00101: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 275ms/step - loss: 2.1325e-04 - mean_absolute_error: 0.0119 - val_loss: 9.1007e-05 - val_mean_absolute_error: 0.0062
# Epoch 102/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0710e-04 - mean_absolute_error: 0.0118
# Epoch 00102: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 284ms/step - loss: 2.0710e-04 - mean_absolute_error: 0.0118 - val_loss: 1.0420e-04 - val_mean_absolute_error: 0.0065
# Epoch 103/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0410e-04 - mean_absolute_error: 0.0116
# Epoch 00103: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 279ms/step - loss: 2.0410e-04 - mean_absolute_error: 0.0116 - val_loss: 1.0466e-04 - val_mean_absolute_error: 0.0063
# Epoch 104/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2712e-04 - mean_absolute_error: 0.0122
# Epoch 00104: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 277ms/step - loss: 2.2712e-04 - mean_absolute_error: 0.0122 - val_loss: 1.0545e-04 - val_mean_absolute_error: 0.0075
# Epoch 105/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2766e-04 - mean_absolute_error: 0.0123
# Epoch 00105: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 279ms/step - loss: 2.2766e-04 - mean_absolute_error: 0.0123 - val_loss: 9.1500e-05 - val_mean_absolute_error: 0.0067
# Epoch 106/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0940e-04 - mean_absolute_error: 0.0120
# Epoch 00106: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 277ms/step - loss: 2.0940e-04 - mean_absolute_error: 0.0120 - val_loss: 1.4609e-04 - val_mean_absolute_error: 0.0101
# Epoch 107/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1840e-04 - mean_absolute_error: 0.0119
# Epoch 00107: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 275ms/step - loss: 2.1840e-04 - mean_absolute_error: 0.0119 - val_loss: 1.1443e-04 - val_mean_absolute_error: 0.0072
# Epoch 108/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2369e-04 - mean_absolute_error: 0.0121
# Epoch 00108: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 277ms/step - loss: 2.2369e-04 - mean_absolute_error: 0.0121 - val_loss: 1.4325e-04 - val_mean_absolute_error: 0.0087
# Epoch 109/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3542e-04 - mean_absolute_error: 0.0124
# Epoch 00109: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 273ms/step - loss: 2.3542e-04 - mean_absolute_error: 0.0124 - val_loss: 9.4958e-05 - val_mean_absolute_error: 0.0069
# Epoch 110/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2017e-04 - mean_absolute_error: 0.0120
# Epoch 00110: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 279ms/step - loss: 2.2017e-04 - mean_absolute_error: 0.0120 - val_loss: 1.1633e-04 - val_mean_absolute_error: 0.0080
# Epoch 111/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0960e-04 - mean_absolute_error: 0.0115
# Epoch 00111: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 299ms/step - loss: 2.0960e-04 - mean_absolute_error: 0.0115 - val_loss: 1.3348e-04 - val_mean_absolute_error: 0.0085
# Epoch 112/500
# 74/74 [==============================] - ETA: 0s - loss: 2.5027e-04 - mean_absolute_error: 0.0129
# Epoch 00112: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 299ms/step - loss: 2.5027e-04 - mean_absolute_error: 0.0129 - val_loss: 1.1184e-04 - val_mean_absolute_error: 0.0076
# Epoch 113/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2923e-04 - mean_absolute_error: 0.0122
# Epoch 00113: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 294ms/step - loss: 2.2923e-04 - mean_absolute_error: 0.0122 - val_loss: 1.0072e-04 - val_mean_absolute_error: 0.0065
# Epoch 114/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0934e-04 - mean_absolute_error: 0.0119
# Epoch 00114: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 291ms/step - loss: 2.0934e-04 - mean_absolute_error: 0.0119 - val_loss: 1.7054e-04 - val_mean_absolute_error: 0.0091
# Epoch 115/500
# 74/74 [==============================] - ETA: 0s - loss: 2.4407e-04 - mean_absolute_error: 0.0125
# Epoch 00115: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 283ms/step - loss: 2.4407e-04 - mean_absolute_error: 0.0125 - val_loss: 1.9946e-04 - val_mean_absolute_error: 0.0096
# Epoch 116/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1579e-04 - mean_absolute_error: 0.0118
# Epoch 00116: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 275ms/step - loss: 2.1579e-04 - mean_absolute_error: 0.0118 - val_loss: 1.1860e-04 - val_mean_absolute_error: 0.0073
# Epoch 117/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3184e-04 - mean_absolute_error: 0.0121
# Epoch 00117: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 273ms/step - loss: 2.3184e-04 - mean_absolute_error: 0.0121 - val_loss: 1.2252e-04 - val_mean_absolute_error: 0.0071
# Epoch 118/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0878e-04 - mean_absolute_error: 0.0117
# Epoch 00118: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 276ms/step - loss: 2.0878e-04 - mean_absolute_error: 0.0117 - val_loss: 1.2516e-04 - val_mean_absolute_error: 0.0071
# Epoch 119/500
# 74/74 [==============================] - ETA: 0s - loss: 1.9803e-04 - mean_absolute_error: 0.0118
# Epoch 00119: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 273ms/step - loss: 1.9803e-04 - mean_absolute_error: 0.0118 - val_loss: 9.6827e-05 - val_mean_absolute_error: 0.0066
# Epoch 120/500
# 74/74 [==============================] - ETA: 0s - loss: 1.9386e-04 - mean_absolute_error: 0.0115
# Epoch 00120: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 276ms/step - loss: 1.9386e-04 - mean_absolute_error: 0.0115 - val_loss: 1.1817e-04 - val_mean_absolute_error: 0.0083
# Epoch 121/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2848e-04 - mean_absolute_error: 0.0125
# Epoch 00121: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 277ms/step - loss: 2.2848e-04 - mean_absolute_error: 0.0125 - val_loss: 9.7679e-05 - val_mean_absolute_error: 0.0066
# Epoch 122/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0113e-04 - mean_absolute_error: 0.0118
# Epoch 00122: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 274ms/step - loss: 2.0113e-04 - mean_absolute_error: 0.0118 - val_loss: 9.1709e-05 - val_mean_absolute_error: 0.0070
# Epoch 123/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0079e-04 - mean_absolute_error: 0.0116
# Epoch 00123: val_loss improved from 0.00009 to 0.00009, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 20s 277ms/step - loss: 2.0079e-04 - mean_absolute_error: 0.0116 - val_loss: 8.5967e-05 - val_mean_absolute_error: 0.0064
# Epoch 124/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1456e-04 - mean_absolute_error: 0.0119
# Epoch 00124: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 276ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0119 - val_loss: 1.1763e-04 - val_mean_absolute_error: 0.0071
# Epoch 125/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1954e-04 - mean_absolute_error: 0.0119
# Epoch 00125: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 275ms/step - loss: 2.1954e-04 - mean_absolute_error: 0.0119 - val_loss: 9.7062e-05 - val_mean_absolute_error: 0.0068
# Epoch 126/500
# 74/74 [==============================] - ETA: 0s - loss: 1.9257e-04 - mean_absolute_error: 0.0114
# Epoch 00126: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 274ms/step - loss: 1.9257e-04 - mean_absolute_error: 0.0114 - val_loss: 1.1834e-04 - val_mean_absolute_error: 0.0072
# Epoch 127/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0300e-04 - mean_absolute_error: 0.0115
# Epoch 00127: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 278ms/step - loss: 2.0300e-04 - mean_absolute_error: 0.0115 - val_loss: 9.1446e-05 - val_mean_absolute_error: 0.0070
# Epoch 128/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2630e-04 - mean_absolute_error: 0.0121
# Epoch 00128: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 271ms/step - loss: 2.2630e-04 - mean_absolute_error: 0.0121 - val_loss: 1.3669e-04 - val_mean_absolute_error: 0.0070
# Epoch 129/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0357e-04 - mean_absolute_error: 0.0114
# Epoch 00129: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 304ms/step - loss: 2.0357e-04 - mean_absolute_error: 0.0114 - val_loss: 1.2077e-04 - val_mean_absolute_error: 0.0073
# Epoch 130/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2431e-04 - mean_absolute_error: 0.0119
# Epoch 00130: val_loss did not improve from 0.00009
# 74/74 [==============================] - 24s 325ms/step - loss: 2.2431e-04 - mean_absolute_error: 0.0119 - val_loss: 8.9748e-05 - val_mean_absolute_error: 0.0068
# Epoch 131/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1827e-04 - mean_absolute_error: 0.0119
# Epoch 00131: val_loss did not improve from 0.00009
# 74/74 [==============================] - 24s 325ms/step - loss: 2.1827e-04 - mean_absolute_error: 0.0119 - val_loss: 9.7204e-05 - val_mean_absolute_error: 0.0072
# Epoch 132/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3051e-04 - mean_absolute_error: 0.0121
# Epoch 00132: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 302ms/step - loss: 2.3051e-04 - mean_absolute_error: 0.0121 - val_loss: 1.3858e-04 - val_mean_absolute_error: 0.0089
# Epoch 133/500
# 74/74 [==============================] - ETA: 0s - loss: 2.3386e-04 - mean_absolute_error: 0.0121
# Epoch 00133: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 294ms/step - loss: 2.3386e-04 - mean_absolute_error: 0.0121 - val_loss: 1.1343e-04 - val_mean_absolute_error: 0.0082
# Epoch 134/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1642e-04 - mean_absolute_error: 0.0117
# Epoch 00134: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 297ms/step - loss: 2.1642e-04 - mean_absolute_error: 0.0117 - val_loss: 1.1054e-04 - val_mean_absolute_error: 0.0076
# Epoch 135/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0072e-04 - mean_absolute_error: 0.0115
# Epoch 00135: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 287ms/step - loss: 2.0072e-04 - mean_absolute_error: 0.0115 - val_loss: 1.1910e-04 - val_mean_absolute_error: 0.0074
# Epoch 136/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0500e-04 - mean_absolute_error: 0.0117
# Epoch 00136: val_loss did not improve from 0.00009
# 74/74 [==============================] - 21s 282ms/step - loss: 2.0500e-04 - mean_absolute_error: 0.0117 - val_loss: 9.5739e-05 - val_mean_absolute_error: 0.0065
# Epoch 137/500
# 74/74 [==============================] - ETA: 0s - loss: 2.0013e-04 - mean_absolute_error: 0.0113
# Epoch 00137: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 273ms/step - loss: 2.0013e-04 - mean_absolute_error: 0.0113 - val_loss: 1.0227e-04 - val_mean_absolute_error: 0.0075
# Epoch 138/500
# 74/74 [==============================] - ETA: 0s - loss: 2.2672e-04 - mean_absolute_error: 0.0121
# Epoch 00138: val_loss did not improve from 0.00009
# 74/74 [==============================] - 20s 274ms/step - loss: 2.2672e-04 - mean_absolute_error: 0.0121 - val_loss: 1.1705e-04 - val_mean_absolute_error: 0.0069
# Epoch 139/500
# 74/74 [==============================] - ETA: 0s - loss: 1.9982e-04 - mean_absolute_error: 0.0114
# Epoch 00139: val_loss did not improve from 0.00009
# 74/74 [==============================] - 22s 296ms/step - loss: 1.9982e-04 - mean_absolute_error: 0.0114 - val_loss: 1.1203e-04 - val_mean_absolute_error: 0.0073
# Epoch 140/500
# 74/74 [==============================] - ETA: 0s - loss: 2.1598e-04 - mean_absolute_error: 0.0117
# Epoch 00140: val_loss did not improve from 0.00009
# ...
# 74/74 [==============================] - 19s 260ms/step - loss: 1.5884e-04 - mean_absolute_error: 0.0101 - val_loss: 7.4326e-05 - val_mean_absolute_error: 0.0056
# Epoch 453/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7363e-04 - mean_absolute_error: 0.0103
# Epoch 00453: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 257ms/step - loss: 1.7363e-04 - mean_absolute_error: 0.0103 - val_loss: 8.5004e-05 - val_mean_absolute_error: 0.0067
# Epoch 454/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7084e-04 - mean_absolute_error: 0.0107
# Epoch 00454: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 262ms/step - loss: 1.7084e-04 - mean_absolute_error: 0.0107 - val_loss: 8.4264e-05 - val_mean_absolute_error: 0.0062
# Epoch 455/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7233e-04 - mean_absolute_error: 0.0106
# Epoch 00455: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 258ms/step - loss: 1.7233e-04 - mean_absolute_error: 0.0106 - val_loss: 9.3163e-05 - val_mean_absolute_error: 0.0069
# Epoch 456/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7848e-04 - mean_absolute_error: 0.0106
# Epoch 00456: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 259ms/step - loss: 1.7848e-04 - mean_absolute_error: 0.0106 - val_loss: 8.7853e-05 - val_mean_absolute_error: 0.0062
# Epoch 457/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7237e-04 - mean_absolute_error: 0.0105
# Epoch 00457: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 258ms/step - loss: 1.7237e-04 - mean_absolute_error: 0.0105 - val_loss: 9.9026e-05 - val_mean_absolute_error: 0.0063
# Epoch 458/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6842e-04 - mean_absolute_error: 0.0102
# Epoch 00458: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 257ms/step - loss: 1.6842e-04 - mean_absolute_error: 0.0102 - val_loss: 1.0797e-04 - val_mean_absolute_error: 0.0068
# Epoch 459/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6585e-04 - mean_absolute_error: 0.0103
# Epoch 00459: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 260ms/step - loss: 1.6585e-04 - mean_absolute_error: 0.0103 - val_loss: 8.6072e-05 - val_mean_absolute_error: 0.0063
# Epoch 460/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7132e-04 - mean_absolute_error: 0.0108
# Epoch 00460: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 256ms/step - loss: 1.7132e-04 - mean_absolute_error: 0.0108 - val_loss: 8.1130e-05 - val_mean_absolute_error: 0.0060
# Epoch 461/500
# 74/74 [==============================] - ETA: 0s - loss: 1.5622e-04 - mean_absolute_error: 0.0101
# Epoch 00461: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 259ms/step - loss: 1.5622e-04 - mean_absolute_error: 0.0101 - val_loss: 1.0825e-04 - val_mean_absolute_error: 0.0080
# Epoch 462/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7138e-04 - mean_absolute_error: 0.0105
# Epoch 00462: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 256ms/step - loss: 1.7138e-04 - mean_absolute_error: 0.0105 - val_loss: 8.9209e-05 - val_mean_absolute_error: 0.0063
# Epoch 463/500
# 74/74 [==============================] - ETA: 0s - loss: 1.5835e-04 - mean_absolute_error: 0.0102
# Epoch 00463: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 258ms/step - loss: 1.5835e-04 - mean_absolute_error: 0.0102 - val_loss: 7.8116e-05 - val_mean_absolute_error: 0.0060
# Epoch 464/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7669e-04 - mean_absolute_error: 0.0106
# Epoch 00464: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 260ms/step - loss: 1.7669e-04 - mean_absolute_error: 0.0106 - val_loss: 9.8430e-05 - val_mean_absolute_error: 0.0068
# Epoch 465/500
# 74/74 [==============================] - ETA: 0s - loss: 1.8057e-04 - mean_absolute_error: 0.0106
# Epoch 00465: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 256ms/step - loss: 1.8057e-04 - mean_absolute_error: 0.0106 - val_loss: 7.7261e-05 - val_mean_absolute_error: 0.0066
# Epoch 466/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7952e-04 - mean_absolute_error: 0.0106
# Epoch 00466: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 258ms/step - loss: 1.7952e-04 - mean_absolute_error: 0.0106 - val_loss: 1.0915e-04 - val_mean_absolute_error: 0.0075
# Epoch 467/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6453e-04 - mean_absolute_error: 0.0104
# Epoch 00467: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 256ms/step - loss: 1.6453e-04 - mean_absolute_error: 0.0104 - val_loss: 9.0789e-05 - val_mean_absolute_error: 0.0061
# Epoch 468/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6188e-04 - mean_absolute_error: 0.0102
# Epoch 00468: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 258ms/step - loss: 1.6188e-04 - mean_absolute_error: 0.0102 - val_loss: 7.5676e-05 - val_mean_absolute_error: 0.0057
# Epoch 469/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7112e-04 - mean_absolute_error: 0.0102
# Epoch 00469: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 258ms/step - loss: 1.7112e-04 - mean_absolute_error: 0.0102 - val_loss: 9.0550e-05 - val_mean_absolute_error: 0.0063
# Epoch 470/500
# 74/74 [==============================] - ETA: 0s - loss: 1.8140e-04 - mean_absolute_error: 0.0107
# Epoch 00470: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 263ms/step - loss: 1.8140e-04 - mean_absolute_error: 0.0107 - val_loss: 8.4243e-05 - val_mean_absolute_error: 0.0068
# Epoch 471/500
# 74/74 [==============================] - ETA: 0s - loss: 1.5926e-04 - mean_absolute_error: 0.0103
# Epoch 00471: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 270ms/step - loss: 1.5926e-04 - mean_absolute_error: 0.0103 - val_loss: 7.5814e-05 - val_mean_absolute_error: 0.0061
# Epoch 472/500
# 74/74 [==============================] - ETA: 0s - loss: 1.8536e-04 - mean_absolute_error: 0.0107
# Epoch 00472: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 257ms/step - loss: 1.8536e-04 - mean_absolute_error: 0.0107 - val_loss: 1.0771e-04 - val_mean_absolute_error: 0.0077
# Epoch 473/500
# 74/74 [==============================] - ETA: 0s - loss: 1.8279e-04 - mean_absolute_error: 0.0108
# Epoch 00473: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 273ms/step - loss: 1.8279e-04 - mean_absolute_error: 0.0108 - val_loss: 9.3550e-05 - val_mean_absolute_error: 0.0069
# Epoch 474/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7657e-04 - mean_absolute_error: 0.0105
# Epoch 00474: val_loss did not improve from 0.00007
# 74/74 [==============================] - 21s 286ms/step - loss: 1.7657e-04 - mean_absolute_error: 0.0105 - val_loss: 8.8781e-05 - val_mean_absolute_error: 0.0063
# Epoch 475/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6953e-04 - mean_absolute_error: 0.0104
# Epoch 00475: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 267ms/step - loss: 1.6953e-04 - mean_absolute_error: 0.0104 - val_loss: 8.4901e-05 - val_mean_absolute_error: 0.0060
# Epoch 476/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6800e-04 - mean_absolute_error: 0.0103
# Epoch 00476: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 265ms/step - loss: 1.6800e-04 - mean_absolute_error: 0.0103 - val_loss: 9.2377e-05 - val_mean_absolute_error: 0.0063
# Epoch 477/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7370e-04 - mean_absolute_error: 0.0106
# Epoch 00477: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 269ms/step - loss: 1.7370e-04 - mean_absolute_error: 0.0106 - val_loss: 8.1754e-05 - val_mean_absolute_error: 0.0069
# Epoch 478/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6340e-04 - mean_absolute_error: 0.0102
# Epoch 00478: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 270ms/step - loss: 1.6340e-04 - mean_absolute_error: 0.0102 - val_loss: 8.1432e-05 - val_mean_absolute_error: 0.0066
# Epoch 479/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6385e-04 - mean_absolute_error: 0.0104
# Epoch 00479: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 268ms/step - loss: 1.6385e-04 - mean_absolute_error: 0.0104 - val_loss: 8.3111e-05 - val_mean_absolute_error: 0.0059
# Epoch 480/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6866e-04 - mean_absolute_error: 0.0106
# Epoch 00480: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 273ms/step - loss: 1.6866e-04 - mean_absolute_error: 0.0106 - val_loss: 1.5211e-04 - val_mean_absolute_error: 0.0085
# Epoch 481/500
# 74/74 [==============================] - ETA: 0s - loss: 1.8284e-04 - mean_absolute_error: 0.0109
# Epoch 00481: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 261ms/step - loss: 1.8284e-04 - mean_absolute_error: 0.0109 - val_loss: 8.1048e-05 - val_mean_absolute_error: 0.0062
# Epoch 482/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6674e-04 - mean_absolute_error: 0.0103
# Epoch 00482: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 266ms/step - loss: 1.6674e-04 - mean_absolute_error: 0.0103 - val_loss: 7.7577e-05 - val_mean_absolute_error: 0.0061
# Epoch 483/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6989e-04 - mean_absolute_error: 0.0105
# Epoch 00483: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 277ms/step - loss: 1.6989e-04 - mean_absolute_error: 0.0105 - val_loss: 1.0459e-04 - val_mean_absolute_error: 0.0068
# Epoch 484/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6718e-04 - mean_absolute_error: 0.0104
# Epoch 00484: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 269ms/step - loss: 1.6718e-04 - mean_absolute_error: 0.0104 - val_loss: 7.9449e-05 - val_mean_absolute_error: 0.0060
# Epoch 485/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6808e-04 - mean_absolute_error: 0.0105
# Epoch 00485: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 263ms/step - loss: 1.6808e-04 - mean_absolute_error: 0.0105 - val_loss: 8.1591e-05 - val_mean_absolute_error: 0.0065
# Epoch 486/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6371e-04 - mean_absolute_error: 0.0104
# Epoch 00486: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 264ms/step - loss: 1.6371e-04 - mean_absolute_error: 0.0104 - val_loss: 8.4308e-05 - val_mean_absolute_error: 0.0058
# Epoch 487/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7167e-04 - mean_absolute_error: 0.0104
# Epoch 00487: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 264ms/step - loss: 1.7167e-04 - mean_absolute_error: 0.0104 - val_loss: 7.5907e-05 - val_mean_absolute_error: 0.0059
# Epoch 488/500
# 74/74 [==============================] - ETA: 0s - loss: 1.5110e-04 - mean_absolute_error: 0.0100
# Epoch 00488: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 262ms/step - loss: 1.5110e-04 - mean_absolute_error: 0.0100 - val_loss: 8.2073e-05 - val_mean_absolute_error: 0.0061
# Epoch 489/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7320e-04 - mean_absolute_error: 0.0104
# Epoch 00489: val_loss improved from 0.00007 to 0.00007, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 20s 266ms/step - loss: 1.7320e-04 - mean_absolute_error: 0.0104 - val_loss: 7.3085e-05 - val_mean_absolute_error: 0.0058
# Epoch 490/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6454e-04 - mean_absolute_error: 0.0103
# Epoch 00490: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 262ms/step - loss: 1.6454e-04 - mean_absolute_error: 0.0103 - val_loss: 7.3494e-05 - val_mean_absolute_error: 0.0056
# Epoch 491/500
# 74/74 [==============================] - ETA: 0s - loss: 1.8027e-04 - mean_absolute_error: 0.0104
# Epoch 00491: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 266ms/step - loss: 1.8027e-04 - mean_absolute_error: 0.0104 - val_loss: 8.3719e-05 - val_mean_absolute_error: 0.0062
# Epoch 492/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7581e-04 - mean_absolute_error: 0.0106
# Epoch 00492: val_loss improved from 0.00007 to 0.00007, saving model to results\2021-02-23_AMZN-sh-1-sc-1-sbd-0-huber_loss-adam-LSTM-seq-50-step-15-layers-2-units-256.h5
# 74/74 [==============================] - 20s 265ms/step - loss: 1.7581e-04 - mean_absolute_error: 0.0106 - val_loss: 7.1855e-05 - val_mean_absolute_error: 0.0056
# Epoch 493/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7860e-04 - mean_absolute_error: 0.0105
# Epoch 00493: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 262ms/step - loss: 1.7860e-04 - mean_absolute_error: 0.0105 - val_loss: 7.4642e-05 - val_mean_absolute_error: 0.0059
# Epoch 494/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7021e-04 - mean_absolute_error: 0.0104
# Epoch 00494: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 267ms/step - loss: 1.7021e-04 - mean_absolute_error: 0.0104 - val_loss: 7.7518e-05 - val_mean_absolute_error: 0.0061
# Epoch 495/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6805e-04 - mean_absolute_error: 0.0105
# Epoch 00495: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 263ms/step - loss: 1.6805e-04 - mean_absolute_error: 0.0105 - val_loss: 7.6603e-05 - val_mean_absolute_error: 0.0059
# Epoch 496/500
# 74/74 [==============================] - ETA: 0s - loss: 1.7595e-04 - mean_absolute_error: 0.0106
# Epoch 00496: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 269ms/step - loss: 1.7595e-04 - mean_absolute_error: 0.0106 - val_loss: 8.1929e-05 - val_mean_absolute_error: 0.0059
# Epoch 497/500
# 74/74 [==============================] - ETA: 0s - loss: 1.6657e-04 - mean_absolute_error: 0.0103
# Epoch 00497: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 263ms/step - loss: 1.6657e-04 - mean_absolute_error: 0.0103 - val_loss: 1.0993e-04 - val_mean_absolute_error: 0.0070
# Epoch 498/500
# 74/74 [==============================] - ETA: 0s - loss: 1.5478e-04 - mean_absolute_error: 0.0100
# Epoch 00498: val_loss did not improve from 0.00007
# 74/74 [==============================] - 19s 261ms/step - loss: 1.5478e-04 - mean_absolute_error: 0.0100 - val_loss: 7.6510e-05 - val_mean_absolute_error: 0.0058
# Epoch 499/500
# 74/74 [==============================] - ETA: 0s - loss: 1.5155e-04 - mean_absolute_error: 0.0101
# Epoch 00499: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 275ms/step - loss: 1.5155e-04 - mean_absolute_error: 0.0101 - val_loss: 7.9723e-05 - val_mean_absolute_error: 0.0062
# Epoch 500/500
# 74/74 [==============================] - ETA: 0s - loss: 1.5174e-04 - mean_absolute_error: 0.0101
# Epoch 00500: val_loss did not improve from 0.00007
# 74/74 [==============================] - 20s 265ms/step - loss: 1.5174e-04 - mean_absolute_error: 0.0101 - val_loss: 8.2908e-05 - val_mean_absolute_error: 0.0061

# %%
import matplotlib.pyplot as plt

def plot_graph(test_df):
    """
    This function plots true close price along with predicted close price
    with blue and red colors respectively
    """
    plt.plot(test_df[f'true_adjclose_{LOOKUP_STEP}'], c='b')
    plt.plot(test_df[f'adjclose_{LOOKUP_STEP}'], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

# %%
def get_final_df(model, data):
    """
    This function takes the `model` and `data` dict to 
    construct a final dataframe that includes the features along 
    with true and predicted prices of the testing dataset
    """
    # if predicted future price is higher than the current, 
    # then calculate the true future price minus the current price, to get the buy profit
    buy_profit  = lambda current, true_future, pred_future: true_future - current if pred_future > current else 0
    # if the predicted future price is lower than the current price,
    # then subtract the true future price from the current price
    sell_profit = lambda current, true_future, pred_future: current - true_future if pred_future < current else 0
    X_test = data["X_test"]
    y_test = data["y_test"]
    # perform prediction and get prices
    y_pred = model.predict(X_test)
    if SCALE:
        y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
        y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    test_df = data["test_df"]
    # add predicted future prices to the dataframe
    test_df[f"adjclose_{LOOKUP_STEP}"] = y_pred
    # add true future prices to the dataframe
    test_df[f"true_adjclose_{LOOKUP_STEP}"] = y_test
    # sort the dataframe by date
    test_df.sort_index(inplace=True)
    final_df = test_df
    # add the buy profit column
    final_df["buy_profit"] = list(map(buy_profit, 
                                    final_df["adjclose"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    # add the sell profit column
    final_df["sell_profit"] = list(map(sell_profit, 
                                    final_df["adjclose"], 
                                    final_df[f"adjclose_{LOOKUP_STEP}"], 
                                    final_df[f"true_adjclose_{LOOKUP_STEP}"])
                                    # since we don't have profit for last sequence, add 0's
                                    )
    return final_df

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    if SCALE:
        predicted_price = data["column_scaler"]["adjclose"].inverse_transform(prediction)[0][0]
    else:
        predicted_price = prediction[0][0]
    return predicted_price

# %%
# load optimal model weights from results folder
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# evaluate the model
loss, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
if SCALE:
    mean_absolute_error = data["column_scaler"]["adjclose"].inverse_transform([[mae]])[0][0]
else:
    mean_absolute_error = mae

# get the final dataframe for the testing set
final_df = get_final_df(model, data)

# predict the future price
future_price = predict(model, data)

# we calculate the accuracy by counting the number of positive profits
accuracy_score = (len(final_df[final_df['sell_profit'] > 0]) + len(final_df[final_df['buy_profit'] > 0])) / len(final_df)
# calculating total buy & sell profit
total_buy_profit  = final_df["buy_profit"].sum()
total_sell_profit = final_df["sell_profit"].sum()
# total profit by adding sell & buy together
total_profit = total_buy_profit + total_sell_profit
# dividing total profit by number of testing samples (number of trades)
profit_per_trade = total_profit / len(final_df)

# printing metrics
print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
print(f"{LOSS} loss:", loss)
print("Mean Absolute Error:", mean_absolute_error)
print("Accuracy score:", accuracy_score)
print("Total buy profit:", total_buy_profit)
print("Total sell profit:", total_sell_profit)
print("Total profit:", total_profit)
print("Profit per trade:", profit_per_trade)

plot_graph(final_df)

print(final_df.tail(10))
# save the final dataframe to csv-results folder
csv_results_folder = "csv-results"
if not os.path.isdir(csv_results_folder):
    os.mkdir(csv_results_folder)
csv_filename = os.path.join(csv_results_folder, model_name + ".csv")
final_df.to_csv(csv_filename)
# Out:
# Future price after 15 days is 3186.36$
# huber_loss loss: 7.185461436165497e-05
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-2ff27d45e1d5> in <module>
#      30 print(f"Future price after {LOOKUP_STEP} days is {future_price:.2f}$")
#      31 print(f"{LOSS} loss:", loss)
# ---> 32 print("Mean Absolute Error:", mean_absolute_error)
#      33 print("Accuracy score:", accuracy_score)
#      34 print("Total buy profit:", total_buy_profit)
#
# NameError: name 'mean_absolute_error' is not defined
